# %% [markdown]
# <a href="https://colab.research.google.com/github/MALLI7622/Computer-Vision/blob/master/Visualizing_RGB_Channels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

# %%
# Read in the image
image = mpimg.imread('waymo.jpg')

plt.imshow(image)

# %%
r = image[:,:,0]
g = image[:,:,1]
b = image[:,:,2]
f, (ax1,ax2,ax3) = plt.subplots(1,3,figsize = (20,10))
ax1.set_title('R Channel')
ax1.imshow(r,cmap = 'gray')
ax2.set_title('G Channel')
ax2.imshow(g,cmap = 'gray')
ax3.set_title('B Channel')
ax3.imshow(b,cmap = 'gray')
