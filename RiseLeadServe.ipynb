# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
rise = cv2.imread('rise1.jpg')
rise = cv2.cvtColor(rise, cv2.COLOR_BGR2RGB)
print(rise.shape)
print(type(rise))
plt.imshow(rise)
# Out:
# (567, 970, 3)
# <class 'numpy.ndarray'>

# %%
lead = cv2.imread('lead3.jpg')
lead = cv2.cvtColor(lead, cv2.COLOR_BGR2RGB)
print(lead.shape)
plt.imshow(lead)
# Out:
# (771, 2048, 3)

# %%
serve = cv2.imread('serve.jpeg')
serve = cv2.cvtColor(serve, cv2.COLOR_BGR2RGB)
print(serve.shape)
plt.imshow(serve)
# Out:
# (667, 1000, 3)

# %%
concat_image = cv2.hconcat([lead, lead])
plt.imshow(concat_image)

# %%
cv2.imwrite('opencv_hconcat.jpg', concat_image)
# Out:
# True

# %%
plt.imshow(opencv_concat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-10ae6b75df61> in <module>
# ----> 1 plt.imshow(opencv_concat)
#
# NameError: name 'opencv_concat' is not defined

# %%
opencv_concat = cv2.imread('opencv_hconcat.jpg')
opencv_concat = cv2.cvtColor(opencv_concat, cv2.COLOR_BGR2RGB)
plt.imshow(opencv_concat)

# %%
opencv_concat = cv2.imread('opencv_hconcat.jpg')
#opencv_concat = cv2.cvtColor(opencv_concat, cv2.COLOR_BGR2RGB)
plt.imshow(opencv_concat)

# %%
concat_image = cv2.hconcat([rise, rise])
plt.imshow(concat_image)
cv2.imwrite('opencv_hconcat_rise.jpg', concat_image)
# Out:
# True

# %%
cv2.imwrite('opencv_hconcat_rise.jpg', concat_image)
# Out:
# True

# %%
concat_image = cv2.hconcat([serve, serve])
plt.imshow(concat_image)
cv2.imwrite('opencv_hconcat_serve.jpg', concat_image)
# Out:
# True

# %%
print("Rise", rise.shape)
print("Lead", lead.shape)
print("Serve", serve.shape)
# Out:
# Rise (567, 970, 3)
# Lead (771, 2048, 3)
# Serve (667, 1000, 3)

# %%
rise = np.reshape(rise, (rise.shape))

# %%
plt.imshow(rise)

# %%
from PIL import Image

rise = Image.open("rise1.jpg")
print(rise.size)
rise = rise.crop((300,100,610,567))
print(rise.size)
plt.imshow(rise)
# Out:
# (970, 567)
# (310, 467)

# %%
lead = Image.open("lead3.jpg")
print(lead.size)
lead = lead.crop((1000,100,1800,567))
print(lead.size)
plt.imshow(lead)
# Out:
# (2048, 771)
# (800, 467)

# %%
serve = Image.open("serve.jpeg")
print(serve.size)
serve = serve.crop((10,100,1000,567))
print(serve.size)
plt.imshow(serve)
# Out:
# (1000, 667)
# (990, 467)

# %%
print("Rise", rise.size)
print("Lead", lead.size)
print("Serve", serve.size)
# Out:
# Rise (310, 467)
# Lead (1100, 467)
# Serve (990, 467)

# %%
rise
# Out:
# <PIL.Image.Image image mode=RGB size=310x467 at 0x17029037788>

# %%
type(rise)
# Out:
# PIL.Image.Image

# %%
rise_array = np.array(rise)

# %%
rise_array.shape
# Out:
# (467, 310, 3)

# %%
plt.imshow(rise_array)

# %%
lead_array = np.array(lead)
plt.imshow(lead_array)

# %%
serve_array = np.array(serve)
plt.imshow(serve_array)

# %%
concat_image = cv2.hconcat([rise_array, lead_array])

# %%
plt.imshow(concat_image)

# %%
concat_image = cv2.hconcat([concat_image, serve_array])

# %%
plt.imshow(concat_image)

# %%
cv2.imwrite('rise_hconcat_rise.jpg', concat_image)
# Out:
# True

# %%
rls = Image.open("rise_hconcat_rise.jpg")
rls
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2100x467 at 0x1702A3ED4C8>

# %%
rls = cv2.imread('rise_hconcat_rise.jpg')
#rls_convert = cv2.cvtColor(rls, cv2.COLOR_BGR2RGB)
plt.imshow(rls_convert)

# %%
print("Rise", rise_array.shape)
print("Lead", lead_array.shape)
print("Serve", serve_array.shape)
# Out:
# Rise (467, 310, 3)
# Lead (467, 800, 3)
# Serve (467, 990, 3)

# %%
image = cv2.imread('rise_hconcat_rise.jpg')

# %%
image.shape
# Out:
# (467, 2400, 3)

# %%
blur = cv2.blur(image[290:330],(5,5))

# %%
plt.imshow(blur)

# %%
plt.imshow(image[:,270:335])

# %%
blur = cv2.blur(image[:,270:335], (100,100))
plt.imshow(blur)

# %%
blur = cv2.blur(image, (50,50))
plt.imshow(blur)

# %%
lower_black = np.array([0,0,0])
upper_black = np.array([255, 255, 255])
black_mask = cv2.inRange(image[:,270:335], lower_black, upper_black)

# %%
print(black_mask.shape)
plt.imshow(black_mask, cmap = "Greys_r")
# Out:
# (467, 65)

# %%
blur.shape
# Out:
# (467, 65, 3)

# %%
black_mask.shape
# Out:
# (467, 65)

# %%
img = np.zeros([467, 65, 3])

# %%
plt.imshow(img)

# %%
new_img = blur + img

# %%
plt.imshow(new_img, cmap = "Greys_r")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
