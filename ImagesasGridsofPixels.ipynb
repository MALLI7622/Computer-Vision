# %% [markdown]
# <a href="https://colab.research.google.com/github/MALLI7622/Computer-Vision/blob/master/ImagesasGridsofPixels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import cv2

# %%
image = mpimg.imread('honda.jpg')

print("Image Dimenasion : ", image.shape)

plt.imshow(image)
# Out:
# Image Dimenasion :  (1080, 1920, 3)

# %%
 gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap = "Greys_r")

# %%
 gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap = "Accent")

# %%
 gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap = "Accent_r")

# %%
 gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap = "Blues")

# %%
 gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap = "Blues_r")

# %%
 gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap = "BrBG")

# %%
 gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap = "BrBG_r")

# %%
 gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap = "BuGn")

# %%
 gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap = "BuGn_r")

# %%
 gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap = "BuPu")

# %%
 gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap = "BuPu_r")

# %%
 gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap = "CMRmap")

# %%
x = 250
y = 600

pixel_val = gray_image[y,x]
print(pixel_val)
# Out:
# 40
